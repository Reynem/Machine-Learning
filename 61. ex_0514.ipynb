# %% [markdown]
# ## Coding Exercise #0514

# %% [markdown]
# #### 1. Document classification with LSTM network:

# %%
import pandas as pd
import numpy as np
import warnings    
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.datasets.reuters import load_data, get_word_index       # Reuters news data. 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, Embedding
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
warnings.filterwarnings('ignore')                  # Turn the warnings off.
# %matplotlib inline

# %% [markdown]
# #### 1.1. Read in the data:

# %%
n_words = 1000                                        # Size of the vocabulary.
(X_train, y_train), (X_test, y_test) = load_data(num_words = n_words, test_split = 0.3)
n_train_size = X_train.shape[0]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# Check for the shapes.
print("-"*50)
print("Training data X shape: {}".format(X_train.shape))
print("Training data y shape: {}".format(y_train.shape))
print("-"*50)
print("Test data X shape: {}".format(X_test.shape))
print("Test data y shape: {}".format(y_test.shape))
print("-"*50)
# Out:
# --------------------------------------------------
# Training data X shape: (7859,)
# Training data y shape: (7859,)
# --------------------------------------------------
# Test data X shape: (3369,)
# Test data y shape: (3369,)
# --------------------------------------------------

# %% [markdown]
# #### 1.2. Explore the data:

# %%
# Number of unique values of y = Number of categories of the newswires.
n_cat = pd.Series(y_train).nunique()
n_cat
# Out:
# 46

# %%
# Print out an observation (document) contained in X.
# It is encoded as integers (indices).
print(X_train[0])
# Out:
# [1, 2, 2, 8, 43, 10, 447, 5, 25, 207, 270, 5, 2, 111, 16, 369, 186, 90, 67, 7, 89, 5, 19, 102, 6, 19, 124, 15, 90, 67, 84, 22, 482, 26, 7, 48, 4, 49, 8, 864, 39, 209, 154, 6, 151, 6, 83, 11, 15, 22, 155, 11, 15, 7, 48, 9, 2, 2, 504, 6, 258, 6, 272, 11, 15, 22, 134, 44, 11, 15, 16, 8, 197, 2, 90, 67, 52, 29, 209, 30, 32, 132, 6, 109, 15, 17, 12]

# %%
# Let's check for length of the first 100 documents.
# We notice that the length is not uniform.
print([len(a) for a in X_train[0:100]])
# Out:
# [87, 56, 139, 224, 101, 116, 100, 100, 82, 106, 31, 59, 65, 316, 527, 76, 114, 17, 91, 77, 231, 108, 83, 29, 95, 110, 23, 373, 114, 354, 133, 222, 571, 155, 83, 208, 170, 269, 74, 19, 23, 78, 21, 377, 104, 299, 89, 56, 94, 139, 118, 36, 137, 107, 83, 66, 70, 112, 88, 51, 83, 123, 17, 185, 84, 52, 102, 73, 106, 486, 107, 82, 263, 172, 491, 190, 143, 62, 26, 88, 114, 38, 85, 112, 793, 104, 25, 21, 101, 28, 25, 81, 135, 73, 62, 18, 90, 266, 91, 64]

# %%
# Download the dictionary to translate the indices.
my_dict = get_word_index(path='reuters_word_index.json')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters_word_index.json
# 550378/550378 ━━━━━━━━━━━━━━━━━━━━ 1s 1us/step

# %%
# To view the dictionary.
# my_dict

# %%
# Exchange the 'key' and 'value'.
my_dict_inv = {v:k for k,v in my_dict.items()}

# %%
# Translate each document.
i_news = 10                                        # Document number that can be changed at will.
news = list(pd.Series(X_train[i_news]).apply(lambda x: my_dict_inv[x]))
print(' '.join(news))
# Out:
# the federal gain only growth lt they meeting year reuter company did year an they of of reuter company of of 1987 had of of reuter had profits of pct dlrs

# %% [markdown]
# #### 1.3. Data preprocessing:

# %%
# Padding: newswire lengths are uniformly matched to maxlen.
# Cut away if longer than maxlen and fill with 0s if shorter than maxlen.
X_train = sequence.pad_sequences(X_train, maxlen = 100)
X_test = sequence.pad_sequences(X_test, maxlen = 100)

# %%
# Apply one-hot-encoding to the y variable.
y = np.concatenate([y_train,y_test],axis=0)
y = to_categorical(y,46)
y_train = y[:n_train_size,:]
y_test = y[n_train_size:,:]

# %% [markdown]
# #### 1.4. Define the model:

# %%
n_neurons = 100                   # Neurons within each memory cell.
n_input = 100                     # Dimension of the embeding space.

# %%
# LSTM network model.
my_model = Sequential()
my_model.add(Embedding(n_words, n_input))           # n_words = vocabulary size, n_input = dimension of the embedding space.
my_model.add(LSTM(units=n_neurons, return_sequences=False, input_shape=(None, n_input), activation='tanh'))
my_model.add(Dense(n_cat, activation='softmax'))

# %%
# View the summary.
my_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### 1.5. Define the optimizer and compile:

# %%
n_epochs = 20                      # Number of epochs.
batch_size = 20                    # Size of each batch.
learn_rate = 0.001                 # learning rate.

# %%
# Optimizer and compilation.
my_optimizer=Adam(learning_rate=learn_rate)
my_model.compile(loss = "categorical_crossentropy", optimizer = my_optimizer, metrics=["accuracy"])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# #### 1.6. Train the model and visualize the history:

# %%
my_summary = my_model.fit(X_train, y_train, epochs=n_epochs, batch_size = batch_size, validation_split=0.2, verbose = 1)
# Out:
# Epoch 1/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 23s 68ms/step - accuracy: 0.4380 - loss: 2.2484 - val_accuracy: 0.4803 - val_loss: 1.9676
# Epoch 2/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 24s 77ms/step - accuracy: 0.5001 - loss: 1.9072 - val_accuracy: 0.5471 - val_loss: 1.7264
# Epoch 3/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 41s 78ms/step - accuracy: 0.5464 - loss: 1.7985 - val_accuracy: 0.5375 - val_loss: 1.7355
# Epoch 4/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 24s 75ms/step - accuracy: 0.5731 - loss: 1.6463 - val_accuracy: 0.5878 - val_loss: 1.5913
# Epoch 5/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 25s 79ms/step - accuracy: 0.6038 - loss: 1.5471 - val_accuracy: 0.6228 - val_loss: 1.4853
# Epoch 6/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 26s 83ms/step - accuracy: 0.6303 - loss: 1.4450 - val_accuracy: 0.6234 - val_loss: 1.4471
# Epoch 7/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - accuracy: 0.6526 - loss: 1.3468 - val_accuracy: 0.6552 - val_loss: 1.3748
# Epoch 8/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 27s 85ms/step - accuracy: 0.6733 - loss: 1.2702 - val_accuracy: 0.6654 - val_loss: 1.3641
# Epoch 9/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - accuracy: 0.6962 - loss: 1.1823 - val_accuracy: 0.6756 - val_loss: 1.3098
# Epoch 10/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 25s 80ms/step - accuracy: 0.7131 - loss: 1.1059 - val_accuracy: 0.6908 - val_loss: 1.2554
# Epoch 11/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 24s 76ms/step - accuracy: 0.7401 - loss: 1.0166 - val_accuracy: 0.6991 - val_loss: 1.2333
# Epoch 12/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 24s 75ms/step - accuracy: 0.7627 - loss: 0.9330 - val_accuracy: 0.7163 - val_loss: 1.2404
# Epoch 13/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 25s 80ms/step - accuracy: 0.7803 - loss: 0.8587 - val_accuracy: 0.7220 - val_loss: 1.1846
# Epoch 14/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 25s 78ms/step - accuracy: 0.8037 - loss: 0.7811 - val_accuracy: 0.7258 - val_loss: 1.1958
# Epoch 15/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 43s 83ms/step - accuracy: 0.8179 - loss: 0.7245 - val_accuracy: 0.7271 - val_loss: 1.1964
# Epoch 16/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 24s 76ms/step - accuracy: 0.8317 - loss: 0.6643 - val_accuracy: 0.7303 - val_loss: 1.2344
# Epoch 17/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 24s 76ms/step - accuracy: 0.8495 - loss: 0.6015 - val_accuracy: 0.7201 - val_loss: 1.2529
# Epoch 18/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - accuracy: 0.8689 - loss: 0.5392 - val_accuracy: 0.7169 - val_loss: 1.2775
# Epoch 19/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - accuracy: 0.8833 - loss: 0.4870 - val_accuracy: 0.7195 - val_loss: 1.3333
# Epoch 20/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 24s 74ms/step - accuracy: 0.8922 - loss: 0.4418 - val_accuracy: 0.7303 - val_loss: 1.3475

# %%
plt.plot(my_summary.history['accuracy'], c="b")
plt.plot(my_summary.history['val_accuracy'], c="g")
plt.title('Training History')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# %% [markdown]
# #### 1.7. Testing:

# %%
ACC = my_model.evaluate(X_test, y_test, verbose=0)[1]    
print("Test Accuracy : {}".format(np.round(ACC,3)))
# Out:
# Test Accuracy : 0.698
